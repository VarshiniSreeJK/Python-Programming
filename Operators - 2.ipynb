# %% [markdown]
# ### Operators - Part 2

# %% [markdown]
# ### 4. Python Logical Operators
#
# 1. Python logical operators are used to combine conditional statements
# 2. Logical Operators are used to perform certain logical operations on values and variables.
# 3.  In Python, they are used on conditional statements (either True or False), and as a result, they return boolean only (True or False). They are used to combine conditional statements
#
# Logical Operators supported by python
#
# 1. Logical AND
# 2. Logical OR
# 3. Logical NOT

# %% [markdown]
# #### 4.1 Logical AND
#
# - Returns True if both statements are true esle returns fales
#
# -  It is a binary operator, which means to return some value, it has to be operated between two operators
#
# Truth Table
#
# ![Screenshot%202023-10-29%20204200.jpg](attachment:Screenshot%202023-10-29%20204200.jpg)

# %%
x = 5

print(x > 3 and x < 10)
# Out:
# True

# %% [markdown]
# #### 4.2 Logical OR
#
# - Returns True if one of the statements is true
#
# Truth Table
#
# ![Screenshot%202023-10-29%20204534.png](attachment:Screenshot%202023-10-29%20204534.png)

# %%
x = 5

print(x > 3 or x < 4)
# Out:
# True

# %% [markdown]
# #### 4.3 Logical NOT
#
# - 	Reverse the result, returns False if the result is true
#
# Truth Table
#
# ![Screenshot%202023-10-29%20204754.png](attachment:Screenshot%202023-10-29%20204754.png)

# %%
x = 5

print(not(x > 3 and x < 10))
# Out:
# False

# %% [markdown]
# ### 5 Identity Operators
#
# - Used to compare the objects, not if they are equal but if they are actually the same object with same memory location

# %% [markdown]
# #### 5.1 is operator
#
# - Returns True if both variables are the same object

# %%
x = ["john", "britto"]
y = ["john", "britto"]
z = x

print(x is z)

# returns True because z is the same object as x

print(x is y)

# returns False because x is not the same object as y, even if they have the same content

print(x == y)

# to demonstrate the difference betweeen "is" and "==": this comparison returns True because x is equal to y
# Out:
# True
# False
# True

# %% [markdown]
# #### 5.2 is not operator
#
# - Returns True if both variables are not the same object

# %%
x = ["john", "britto"]
y = ["john", "britto"]
z = x

print(x is not z)

# returns False because z is the same object as x

print(x is not y)

# returns True because x is not the same object as y, even if they have the same content

print(x != y)

# to demonstrate the difference betweeen "is not" and "!=": this comparison returns False because x is equal to y
# Out:
# False
# True
# False

# %% [markdown]
# ### 6. Membership Operators
#
# - Membership operators are used to test if a sequence is presented in an object

# %% [markdown]
# #### 6.1 in operator
#
# - 	Returns True if a sequence with the specified value is present in the object

# %%
x = ["priya", "poco"]

print("poco" in x)
# Out:
# True

# %% [markdown]
# #### 6.2 not in operator
#
# - Returns True if a sequence with the specified value is not present in the object

# %%
x = ["priya", "poco"]

print("loco" in x)
# Out:
# False

# %% [markdown]
# ### 7. Bitwise Operators
#
# - This operator is used to compare binary numbers
#
# Python bitwise operators
#
# 1. AND (&)
# 2. OR (|)
# 3. XOR (^)
# 4. NOT (~)
# 5. Zero fill left shift (<<)
# 6. Signed right shift (>>)

# %% [markdown]
# #### 7.1 AND
#
# - Sets each bit to 1 if both bits are 1 else 0

# %% [markdown]
# The & operator compares each bit and set it to 1 if both are 1, otherwise it is set to 0:
#
# 6 = 0000000000000110
# 3 = 0000000000000011
# --------------------
# 2 = 0000000000000010
# ====================
#
# Decimal numbers and their binary values:
# 0 = 0000000000000000
# 1 = 0000000000000001
# 2 = 0000000000000010
# 3 = 0000000000000011
# 4 = 0000000000000100
# 5 = 0000000000000101
# 6 = 0000000000000110
# 7 = 0000000000000111

# %%
(6&3)
# Out:
# 2

# %% [markdown]
# #### 7.2 OR
#
# - 	Sets each bit to 1 if one of two bits is 1

# %%
print(6 | 3)
# Out:
# 7

# %% [markdown]
# #### 7.3 XOR(^)
#
# - 	Sets each bit to 1 if only one of two bits is 1

# %%
(6^3)
# Out:
# 5

# %% [markdown]
# #### 7.4 NOT (~)
#
# - 	Inverts all the bits

# %%
(~3)
# Out:
# -4

# %% [markdown]
# #### 7.5 Zero fill left shift (<<)
#
# - Shift left by pushing zeros in from the right and let the leftmost bits fall off

# %%
(3<<2)
# Out:
# 12

# %% [markdown]
# #### 7.6 Signed right shift (>>)
#
# - Shift right by pushing copies of the leftmost bit in from the left, and let the rightmost bits fall off

# %%
(8>>2)
# Out:
# 2

# %% [markdown]
# ### Operator Precedence
#
# - Describes the order in which the operations are performed
#
# - This is used in an expression with more than one operator with different precedence to determine which operation to perform first.
#
# Precedence order (Highest to lowest)
#
# P - PARANTHESIS
#
# E - EXPONENTIATION
#
# M - MULTIPLICATION
#
# D - DIVISION
#
# A - ADDITION
#
# S - SUBTRACTION
#
# - If two operators have same precendence the expression is evaluated from left to right.

# %%
#Parentheses has the highest precedence, meaning that expressions inside parentheses must be evaluated first
((6+3) - (6+3))
# Out:
# 0

# %%
#Multiplication * has higher precedence than addition +, and therefor multiplications are evaluated before additions
(100+5*3)
# Out:
# 115

# %%
#Addition + and subtraction - has the same precedence, and therefor we evaluate the expression from left to right
(5+4-7+3)
# Out:
# 5

# %% [markdown]
# ### Precedence Order (Highest to lowest)
#
# 1. Paranthesis -()
#
# 2. Exponentiation - **
#
# 3. Unary plus, unary minus, and bitwise NOT ( +x , -x , ~x)
#
# 4. Multiplication, division, floor division and modulus (* , /, //, %)
#
# 5. Addition and subtraction (=, -)
#
# 6. Bitwise left and right shifts (<<, >>)
#
# 7. Bitwise AND (&)
#
# 8. Bitwsie XOR (^)
#
# 9. Bitwise OR (|)
#
# 10. Comparisons, identity and membership operators (== , !=,  >,  >=,  <,  <=,  is,  is not,  in,  not in)
#
# 11. Logical NOT (not)
#
# 12. AND (and)
#
# 13. OR (or)

# %% [markdown]
# #### Paranthesis
#
# - Parenthesis have the highest precedence, and need to be evaluated first

# %%
((5+4)- (5+4))
# Out:
# 0

# %% [markdown]
# #### Exponentiation
#
# - Exponentiation has higher precedence than subtraction, and needs to be evaluated first

# %%
(1000-3 ** 3)
# Out:
# 973

# %% [markdown]
# #### Unary plus, unary minus and bitwise NOT
#
# - Bitwise NOT has higher precedence than addition, and needs to be evaluated first.

# %%
(100 +~5)
# Out:
# 94

# %% [markdown]
# #### Multiplication, division, floor division and  modulus
#
# - Multiplication has higher precedence than addition, and needs to be evaluated first

# %%
(10+5 *6)
# Out:
# 40

# %% [markdown]
# #### Addition and subtraction
#
# - Subtraction has a lower precedence than multiplication, and we need to calculate the multiplication first

# %%
(100-10 *5 )
# Out:
# 50

# %% [markdown]
# #### Bitwise left and right shifts
#
# - Bitwise right shift has a lower precedence than subtraction, and we need to calculate the subtraction first.
# The calculation above reads 8 >> 2 = 2
#
# More explanation:
# The >> operator moves each bit the specified number of times to the right. Empty holes at the left are filled with 0's

# %%
(8 >> 4-2)
# Out:
# 2

# %% [markdown]
# #### Bitwise AND
#
# - Bitwise AND has a lower precedence than addition, and we need to calculate the addition first.
#
# - The calculation reads 6 & 3 = 2
#
# More explanation:
#
# - The & operator compares each bit and set it to 1 if both are 1, otherwise it is set to 0

# %%
(6 & 2 +1 )
# Out:
# 2

# %% [markdown]
# #### Bitwise XOR
#
# - Bitwise XOR has a lower precedence than addition, and we need to calculate the addition first.
#
# - The calculation reads 6 ^ 3 = 5
#
#
# More explanation:
#
# - The ^ operator compares each bit and set it to 1 if only one is 1, otherwise (if both are 1 or both are 0) it is set to 0

# %%
(6^2 +1)
# Out:
# 5

# %% [markdown]
# #### Bitwise OR
#
# - Bitwise OR has a lower precedence than addition, and we need to calculate the addition first.
#
# - The calculation reads 6 | 3 = 7
#
# More explanation:
#
# - The | operator compares each bit and set it to 1 if one or both is 1, otherwise it is set to 0

# %%
(6|2 +1)
# Out:
# 7

# %% [markdown]
# #### Comparisons, identity and membership operators
#
# - The "like" comparison has a lower precedence than addition, and we need to calculate the addition first.
#
#
# - The calculation reads 5 == 5 = True

# %%
(5==4+1)
# Out:
# True

# %% [markdown]
# #### Logical NOT
#
# - The logical NOT operator has a lower precedence than "like" comparison, and we need to calculate the comparison first.
#
# - The calculation reads: not True = False

# %%
(not 5==5)
# Out:
# False

# %% [markdown]
# #### AND
#
# - The and operator has a higher precedence than or, and we need to calculate the and expression first.
#
# - The calculation reads: 1 or 3 = 1

# %%
(1 or 2 and 3)
# Out:
# 1

# %% [markdown]
# #### OR
#
# - The or operator has a lower precedence than addition, and we need to calculate the addition first.
#
# - The calculation reads: 4 or 15 or 8 = 4

# %%
(4 or 5 + 10 or 8)
# Out:
# 4

# %% [markdown]
# ##### Learning Source: w3 Schools and GFG
